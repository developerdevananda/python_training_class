# %% [markdown]
# <a href="https://colab.research.google.com/github/developerdevananda/python_training_class/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range(n):
   m = int(input("enter the number"))
   a.append(m)
   print(a)

print("smallest element is",min(a))
# Out:
# enter the number of elements4
# enter the number6
# [6]
# enter the number3
# [6, 3]
# enter the number8
# [6, 3, 8]
# enter the number2
# [6, 3, 8, 2]
# smallest element is 2

# %%
K=[]
n=int(input("entr the no of elements:"))
for i in range(n):
  K.append(int(input("enter the elements:")))
  print(K)
# Out:
# entr the no of elements:4
# enter the elements:5
# [5]
# enter the elements:4
# [5, 4]
# enter the elements:6
# [5, 4, 6]
# enter the elements:8
# [5, 4, 6, 8]

# %%
n= int(input("enter the number of elements:"))
a =[]

for i in range(n):
  m = int(input("enter the element:"))
  a.append(m)
print(a)
print( "The sum of elements is",sum(a))
# Out:
# enter the number of elements:3
# enter the element:4
# enter the element:4
# enter the element:3
# [4, 4, 3]
# The sum of elements is 11

# %%
s=[]
n=int(input("Enter limit:"))
for i in range(n):
  s.append(int(input("Enter the elements:")))
print(s)
print("reversed list is ",s[::-1])
# Out:
# Enter limit:3
# Enter the elements:4
# Enter the elements:9
# Enter the elements:7
# [4, 9, 7]
# reversed list is  [7, 9, 4]

# %%
s=[]
n=int(input("Enter limit: "))
for i in range(n):
  a=int(input("Enter element: "))
  s.append(a)
a=int(input(" enter element to be searched "))
if a in s:
  print("Element exist")
else:
  print("Element doesn't exist")
# Out:
# Enter limit: 5
# Enter element: 3
# Enter element: 5
# Enter element: 2
# Enter element: 4
# Enter element: 6
#  enter element to be searched 4
# Element exist

# %%
r=[]
n=int(input("enter array limit"))
for i in range(n):
    r.append(int(input("enter a number")))
num = int(input("Enter number to count: "))
print("Number of occurrences:", r.count(num))
# Out:
# enter array limit4
# enter a number2
# enter a number4
# enter a number5
# enter a number6
# Enter number to count: 6
# Number of occurrences: 1

# %%
r=[]
n=int(input("Enter the number of elments"))
for i in range(n):
  num=(int(input("Enter the elemnts")))
  r.append(num)
r.sort()
print("Second largest element",r[-2])
# Out:
# Enter the number of elments3
# Enter the elemnts2
# Enter the elemnts4
# Enter the elemnts6
# Second largest element 4

# %%
p=[]
m=int(input("enter no of elements:"))
for i in range(m):
  p.append(int(input("enter the element:")))
print(p)
print(list(set(p)))
# Out:
# enter no of elements:3
# enter the element:4
# enter the element:5
# enter the element:3
# [4, 5, 3]
# [3, 4, 5]

# %%
p=[]
n=int(input("enter the number of elments"))
for i in range(n):
  num=int(input("emter the elements"))
  p.append(num)
  p.sort()
  print("sorted array",p)
# Out:
# enter the number of elments4
# emter the elements5
# sorted array [5]
# emter the elements6
# sorted array [5, 6]
# emter the elements4
# sorted array [4, 5, 6]
# emter the elements2
# sorted array [2, 4, 5, 6]

# %%
w=map(int,(input("Enter the elements: ").split()))
print(list(w))
# Out:
# Enter the elements: 3
# [3]

# %%
s=input("enter a string")
print(s[::-1])
# Out:
# enter a stringgfhdhd
# dhdhfg

# %%
n=int(input("Enter the number:"))
a=0
while n>0:
 r=n%10
 a=a*10+r
 n=n//10
print("Reversed:",a)
# Out:
# Enter the number:65459
# Reversed: 95456

# %%
n=int(input("enter a num:"))
sum=0
while(n>0):
  rem=n%10
  sum=sum+rem
  n=n//10
print("sum:",sum)
# Out:
# enter a num:56
# sum: 11

# %%
n=int(input("enter the no"))
a=0
while (n>0):
  r=n%10
  if r>a:
    a=r
    n=n//10
    print("largest:",a)
# Out:
# enter the no852
# largest: 2
# largest: 5
# largest: 8

# %%
n=input("enter the no")
if n==n[::-1]:
   print("palimdrome")
else:
    print("not palindrome")
# Out:
# enter the no85
# not palindrome

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
if sorted(str1) == sorted(str2):
    print("Anagram")
else:
    print("Not anagram")
# Out:
# Enter first string: gtrtr
# Enter second string: ffdfd
# Not anagram

# %%
s=input("Enter the string: ")
print("count of character using len() =",len(s))
count=0
for char in s:
  count+=1
print(" without using built-in function =",count)
# Out:
# Enter the string: bfddj
# count of character using len() = 5
#  without using built-in function = 5

# %%
str= input("Enter a string: ")
s = ""
for char in str:
    if char not in s:
       s = s + char
print("Without duplicates:",s)
# Out:
# Enter a string: bsdgfvsf
# Without duplicates: bsdgfv

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)
# Out:
# Ënter a string:fsfaw
# No. of vowels: 1
# No of consonants: 4
